# %%
import sys
sys.path.append("../src") # path to evansplot src dir
import evansplot

import xarray as xr

# %%
import importlib
importlib.reload(evansplot.plotters)
# Out:
# <module 'evansplot' from '/Users/stefan/Stef & Mel Dropbox/stefan gregory/PROGRAMMING/CCRC/People/Jason/evansplot.py'>

# %%
gcm_ds = xr.open_dataset("gcm_co2_pre.nc")

# %%
evansplot.evans_plot(gcm_ds, 
                     title = "Change in Precipitation",
                     hue_var="anpre48_00", 
                     sat_var="per_anpre48_00",
                     num_sat_levels=4,
                     min_sat=-20,max_sat=20,
                     hue_label="mm", sat_label="%",
                     )

# %%
evansplot.evans_plot(gcm_ds, 
                     title = "Change in Precipitation",
                     hue_var="anpre48_00", 
                     sat_var="per_anpre48_00",
                     hue_label="mm", sat_label="%",
                     )

# %%
evansplot.evans_plot(gcm_ds, 
                     title = "Change in Precipitation",
                     hue_var="anpre48_00", 
                     sat_var="per_anpre48_00",
                     num_sat_levels=6,
                     min_sat=2.5,max_sat=17.5,
                     hue_label="mm", sat_label="%",
                     )
